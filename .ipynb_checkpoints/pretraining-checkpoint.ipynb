# %%
import random
import time
import warnings
from datetime import datetime

import torch
import os

import numpy as np
import warnings
np.warnings = warnings
import matplotlib.pyplot as plt
from tabpfn_new.scripts.differentiable_pfn_evaluation import eval_model_range
from tabpfn_new.scripts.model_builder import get_model, get_default_spec, save_model, load_model
from tabpfn_new.scripts.transformer_prediction_interface import transformer_predict, get_params_from_config, load_model_workflow

from tabpfn_new.scripts.model_configs import *

#from datasets import load_openml_list, open_cc_dids, open_cc_valid_dids
from tabpfn_new.priors.utils import plot_prior, plot_features
from tabpfn_new.priors.utils import uniform_int_sampler_f

from tabpfn_new.scripts.tabular_metrics import calculate_score_per_method, calculate_score
from tabpfn_new.scripts.tabular_evaluation import evaluate

from tabpfn_new.priors.differentiable_prior import DifferentiableHyperparameterList, draw_random_style, merge_style_with_info
from tabpfn_new.scripts import tabular_metrics
from tabpfn.notebook_utils import *

# %%
device = 'cpu'
base_path = '.'
max_features = 100

# %%
def reload_config(prior_type='forest', config_type='causal', task_type='binary', longer=0):
    config = get_prior_config(config_type=config_type)
    
    config['prior_type'] = prior_type
    
    model_string = ''
    
    config['epochs'] = 12000
    config['recompute_attn'] = True

    config['max_num_classes'] = 10
    config['num_classes'] = uniform_int_sampler_f(2, config['max_num_classes'])
    config['balanced'] = False
    model_string = model_string + '_multiclass'
    
    model_string = model_string + '_'+datetime.now().strftime("%m_%d_%Y_%H_%M_%S")
    
    return config, model_string

# %%
prior_type = 'mlp'
config, model_string = reload_config(prior_type, longer=1)

config['differentiable'] = True
config['flexible'] = True
config['bptt_extra_samples'] = None

# diff
config['output_multiclass_ordered_p'] = 0.0
del config['differentiable_hyperparameters']['output_multiclass_ordered_p']



config['sampling'] = 'normal' # vielleicht schlecht?
del config['differentiable_hyperparameters']['sampling']

config['pre_sample_causes'] = True
# end diff

config['multiclass_loss_type'] = 'nono' # 'compatible'

config['categorical_feature_p'] = 0 # diff: .0

# turn this back on in a random search!?
config['nan_prob_no_reason'] = .0
config['nan_prob_unknown_reason'] = .0 # diff: .0
config['set_value_to_nan'] = .0 # diff: 1.


config['new_mlp_per_example'] = True
config['prior_mlp_scale_weights_sqrt'] = True
config['batch_size_per_gp_sample'] = None



config['differentiable_hps_as_style'] = False
config['max_eval_pos'] = 1000

config['random_feature_rotation'] = True
config['rotate_normalized_labels'] = True

config["mix_activations"] = True # False heisst eig True

config['emsize'] = 512
config['nhead'] = config['emsize'] // 128
config['bptt'] = 1024+128
config['canonical_y_encoder'] = False


config['total_available_time_in_s'] = None #60*60*22 # 22 hours for some safety...

config['train_mixed_precision'] = False
config['efficient_eval_masking'] = True

# mlp params
config['is_causal'] = True
config['num_causes'] = 5
config['prior_mlp_hidden_dim'] = 50
config['num_layers'] = 4
config['noise_std'] = 0.05
config['init_std'] = 0.05
config['y_is_effect'] = True
config['pre_sample_weights'] = True
config['prior_mlp_dropout_prob'] = 0
config['pre_sample_causes'] = True
config["prior_mlp_activations"] = torch.nn.ReLU
config["block_wise_dropout"] = True
config["sort_features"] = False
config["in_clique"] = False

# general data params
config['balanced'] = True
config['max_num_classes'] = 10
config['max_features'] = 100
config['num_features_used'] = 100

config['differentiable'] = True
config['flexible'] = True

# forest params
config["min_features"] = 100
config["max_features"] = 100
config["n_samples"] = 1000
config["max_num_classes"] = 2
config["base_size"] = 1000
config["n_estimators"] = 1
config["min_depth"] = 1
config["max_depth"] = 25
config["categorical_x"] = False
config["data_sample_func"] = "mnd"
config["comp"] = False

config['no_encoder'] = False
config['normalize_to_ranking'] = False # False
config['normalize_with_sqrt'] = False
config['normalize_ignore_label_too'] = False
config["normalize"] = False
config['num_classes'] = 2

config["balanced"] = True
config['multiclass_type'] = 'imbalanced_binarize'
del config['differentiable_hyperparameters']['multiclass_type']

config["prior_type"] = "forest"
config["microbiome_test"] = True
config["weight_classes"] = True
config["run_name"] = "forest_balanced"

    
config['aggregate_k_gradients'] = 64
config['batch_size'] = 1*config['aggregate_k_gradients']
config['num_steps'] = 64*4//config['aggregate_k_gradients']
config['epochs'] = 50

config["lr"] = 1e-6

config_sample = evaluate_hypers(config)
'''for key in config_sample:
    #if key == "check_is_compatible":
    print(key, config_sample[key])
for key in config_sample["differentiable_hyperparameters"]:
    print(key, config_sample["differentiable_hyperparameters"][key])'''
# Out:
# 'for key in config_sample:\n    #if key == "check_is_compatible":\n    print(key, config_sample[key])\nfor key in config_sample["differentiable_hyperparameters"]:\n    print(key, config_sample["differentiable_hyperparameters"][key])'

# %%
model = get_model(config_sample, device, should_train=True, verbose=1)
# Out:
# Using style prior: True
# Using cpu:0 device
# Using a Transformer with 25.81 M parameters
# tensor(0.5415)
# % positive predictions:  tensor([0.0041]) % Positive targets :  tensor([0.9221])
# Train sample accuracy:  tensor(0.0738)
# tensor(0.4827)
# % positive predictions:  tensor([0.0035]) % Positive targets :  tensor([0.9371])
# Train sample accuracy:  tensor(0.0664)
# tensor(0.4856)
# % positive predictions:  tensor([0.1695]) % Positive targets :  tensor([0.0536])
# Train sample accuracy:  tensor(0.7983)
# tensor(0.4897)
# % positive predictions:  tensor([0.1204]) % Positive targets :  tensor([0.9501])
# Train sample accuracy:  tensor(0.1616)
# % of positive predictions:  0.59
#                     accuracy  precision    recall  roc_auc
# Micriobiome TabPFN  0.394032   0.047997  0.465499   0.4274
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 380.49s | mean loss  0.70 |  lr1e-06 |  data time  0.02 step time  1.20 forward time  0.35 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4804)
# % positive predictions:  tensor([0.1593]) % Positive targets :  tensor([0.9724])
# Train sample accuracy:  tensor(0.1794)
# tensor(0.4895)
# % positive predictions:  tensor([0.0882]) % Positive targets :  tensor([1.])
# Train sample accuracy:  tensor(0.0882)
# tensor(0.5054)
# % positive predictions:  tensor([0.4919]) % Positive targets :  tensor([0.9899])
# Train sample accuracy:  tensor(0.4879)
# tensor(0.5406)
# % positive predictions:  tensor([0.6136]) % Positive targets :  tensor([0.9990])
# Train sample accuracy:  tensor(0.6126)
# % of positive predictions:  0.61
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.446036   0.048035  0.445225  0.445596
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 339.59s | mean loss  0.70 |  lr9.990133642141357e-07 |  data time  0.03 step time  0.92 forward time  0.30 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4983)
# % positive predictions:  tensor([0.8323]) % Positive targets :  tensor([0.1706])
# Train sample accuracy:  tensor(0.2997)
# tensor(0.5421)
# % positive predictions:  tensor([0.7937]) % Positive targets :  tensor([1.])
# Train sample accuracy:  tensor(0.7937)
# tensor(0.5316)
# % positive predictions:  tensor([0.1046]) % Positive targets :  tensor([0.0077])
# Train sample accuracy:  tensor(0.8938)
# tensor(0.5338)
# % positive predictions:  tensor([0.0620]) % Positive targets :  tensor([0.9708])
# Train sample accuracy:  tensor(0.0912)
# % of positive predictions:  0.515
#                     accuracy  precision   recall   roc_auc
# Micriobiome TabPFN  0.498384   0.048264  0.38434  0.445066
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 309.33s | mean loss  0.70 |  lr9.960573506572389e-07 |  data time  0.02 step time  1.42 forward time  0.50 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5496)
# % positive predictions:  tensor([0.3886]) % Positive targets :  tensor([0.0157])
# Train sample accuracy:  tensor(0.6068)
# tensor(0.5161)
# % positive predictions:  tensor([0.2041]) % Positive targets :  tensor([0.1917])
# Train sample accuracy:  tensor(0.6841)
# tensor(0.5003)
# % positive predictions:  tensor([0.1532]) % Positive targets :  tensor([0.6448])
# Train sample accuracy:  tensor(0.4090)
# tensor(0.4871)
# % positive predictions:  tensor([0.0594]) % Positive targets :  tensor([0.0891])
# Train sample accuracy:  tensor(0.8729)
# % of positive predictions:  0.32
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN   0.52814   0.044176  0.352011  0.445461
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 329.15s | mean loss  0.69 |  lr9.911436253643443e-07 |  data time  0.02 step time  1.03 forward time  0.36 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4850)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.0087])
# Train sample accuracy:  tensor(0.0087)
# tensor(0.5272)
# % positive predictions:  tensor([0.7585]) % Positive targets :  tensor([0.0075])
# Train sample accuracy:  tensor(0.2415)
# tensor(0.4874)
# % positive predictions:  tensor([0.1066]) % Positive targets :  tensor([0.0035])
# Train sample accuracy:  tensor(0.8900)
# tensor(0.4644)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0156])
# Train sample accuracy:  tensor(0.9844)
# % of positive predictions:  0.43
#                     accuracy  precision   recall   roc_auc
# Micriobiome TabPFN  0.569148   0.046156  0.30239  0.444591
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 304.88s | mean loss  0.68 |  lr9.842915805643156e-07 |  data time  0.02 step time  1.41 forward time  0.51 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4650)
# % positive predictions:  tensor([0.2040]) % Positive targets :  tensor([0.0050])
# Train sample accuracy:  tensor(0.8010)
# tensor(0.4631)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.0379])
# Train sample accuracy:  tensor(0.0379)
# tensor(0.4682)
# % positive predictions:  tensor([0.1244]) % Positive targets :  tensor([0.9948])
# Train sample accuracy:  tensor(0.1295)
# tensor(0.4915)
# % positive predictions:  tensor([0.1598]) % Positive targets :  tensor([0.0731])
# Train sample accuracy:  tensor(0.8037)
# % of positive predictions:  0.355
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN   0.59602   0.046806  0.301757  0.458111
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 315.65s | mean loss  0.68 |  lr9.755282581475767e-07 |  data time  0.02 step time  1.21 forward time  0.50 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5627)
# % positive predictions:  tensor([0.4484]) % Positive targets :  tensor([0.7881])
# Train sample accuracy:  tensor(0.4411)
# tensor(0.5092)
# % positive predictions:  tensor([0.8458]) % Positive targets :  tensor([0.0406])
# Train sample accuracy:  tensor(0.1912)
# tensor(0.5011)
# % positive predictions:  tensor([0.8283]) % Positive targets :  tensor([0.3638])
# Train sample accuracy:  tensor(0.4075)
# tensor(0.4925)
# % positive predictions:  tensor([0.0679]) % Positive targets :  tensor([0.8660])
# Train sample accuracy:  tensor(0.2019)
# % of positive predictions:  0.355
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.632669   0.051217  0.296003  0.475017
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 260.31s | mean loss  0.68 |  lr9.648882429441256e-07 |  data time  0.02 step time  1.46 forward time  0.40 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5279)
# % positive predictions:  tensor([0.2995]) % Positive targets :  tensor([0.0481])
# Train sample accuracy:  tensor(0.7059)
# tensor(0.4860)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0096])
# Train sample accuracy:  tensor(0.9904)
# tensor(0.4972)
# % positive predictions:  tensor([0.6308]) % Positive targets :  tensor([0.0974])
# Train sample accuracy:  tensor(0.3744)
# tensor(0.4953)
# % positive predictions:  tensor([0.3803]) % Positive targets :  tensor([0.9376])
# Train sample accuracy:  tensor(0.3742)
# % of positive predictions:  0.32
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.657623   0.047743  0.243965  0.464236
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 257.49s | mean loss  0.68 |  lr9.524135262330098e-07 |  data time  0.03 step time  1.18 forward time  0.42 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4605)
# % positive predictions:  tensor([0.1020]) % Positive targets :  tensor([0.9197])
# Train sample accuracy:  tensor(0.1715)
# tensor(0.4748)
# % positive predictions:  tensor([0.3202]) % Positive targets :  tensor([0.2719])
# Train sample accuracy:  tensor(0.5931)
# tensor(0.4950)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.1951])
# Train sample accuracy:  tensor(0.8049)
# tensor(0.4951)
# % positive predictions:  tensor([0.6873]) % Positive targets :  tensor([0.1835])
# Train sample accuracy:  tensor(0.3773)
# % of positive predictions:  0.3
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.694183   0.050802  0.212988  0.469897
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 263.12s | mean loss  0.67 |  lr9.381533400219317e-07 |  data time  0.02 step time  1.14 forward time  0.40 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5271)
# % positive predictions:  tensor([0.1172]) % Positive targets :  tensor([0.3223])
# Train sample accuracy:  tensor(0.5824)
# tensor(0.5340)
# % positive predictions:  tensor([0.5098]) % Positive targets :  tensor([0.6708])
# Train sample accuracy:  tensor(0.1806)
# tensor(0.5399)
# % positive predictions:  tensor([0.9532]) % Positive targets :  tensor([0.9940])
# Train sample accuracy:  tensor(0.9472)
# tensor(0.5308)
# % positive predictions:  tensor([0.2809]) % Positive targets :  tensor([0.0067])
# Train sample accuracy:  tensor(0.7258)
# % of positive predictions:  0.285
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.721839   0.046297  0.177892  0.467808
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 249.62s | mean loss  0.67 |  lr9.221639627510075e-07 |  data time  0.03 step time  1.07 forward time  0.43 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5746)
# % positive predictions:  tensor([0.5948]) % Positive targets :  tensor([0.9573])
# Train sample accuracy:  tensor(0.5806)
# tensor(0.6040)
# % positive predictions:  tensor([0.5121]) % Positive targets :  tensor([0.6466])
# Train sample accuracy:  tensor(0.4960)
# tensor(0.5576)
# % positive predictions:  tensor([0.5687]) % Positive targets :  tensor([0.0217])
# Train sample accuracy:  tensor(0.4356)
# tensor(0.5413)
# % positive predictions:  tensor([0.3939]) % Positive targets :  tensor([0.6783])
# Train sample accuracy:  tensor(0.2123)
# % of positive predictions:  0.225
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.755432   0.051866  0.176732  0.484647
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 256.38s | mean loss  0.66 |  lr9.045084971874737e-07 |  data time  0.02 step time  0.91 forward time  0.27 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5189)
# % positive predictions:  tensor([0.1653]) % Positive targets :  tensor([0.2966])
# Train sample accuracy:  tensor(0.7076)
# tensor(0.5088)
# % positive predictions:  tensor([0.0777]) % Positive targets :  tensor([0.0078])
# Train sample accuracy:  tensor(0.9145)
# tensor(0.5031)
# % positive predictions:  tensor([0.2698]) % Positive targets :  tensor([0.0101])
# Train sample accuracy:  tensor(0.7234)
# tensor(0.4985)
# % positive predictions:  tensor([0.4993]) % Positive targets :  tensor([0.8645])
# Train sample accuracy:  tensor(0.4665)
# % of positive predictions:  0.205
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.801414   0.062362  0.169248  0.505084
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 256.73s | mean loss  0.66 |  lr8.852566213878946e-07 |  data time  0.02 step time  1.06 forward time  0.36 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5418)
# % positive predictions:  tensor([0.7870]) % Positive targets :  tensor([0.6761])
# Train sample accuracy:  tensor(0.5511)
# tensor(0.5527)
# % positive predictions:  tensor([0.8524]) % Positive targets :  tensor([0.9025])
# Train sample accuracy:  tensor(0.7549)
# tensor(0.5238)
# % positive predictions:  tensor([0.2072]) % Positive targets :  tensor([0.8785])
# Train sample accuracy:  tensor(0.2913)
# tensor(0.5256)
# % positive predictions:  tensor([0.4776]) % Positive targets :  tensor([0.3041])
# Train sample accuracy:  tensor(0.5286)
# % of positive predictions:  0.15
#                     accuracy  precision    recall  roc_auc
# Micriobiome TabPFN   0.80726   0.054643  0.122223  0.48825
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 236.35s | mean loss  0.66 |  lr8.644843137107057e-07 |  data time  0.03 step time  1.08 forward time  0.40 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5119)
# % positive predictions:  tensor([0.1813]) % Positive targets :  tensor([0.0100])
# Train sample accuracy:  tensor(0.8127)
# tensor(0.4881)
# % positive predictions:  tensor([0.9133]) % Positive targets :  tensor([0.2511])
# Train sample accuracy:  tensor(0.3018)
# tensor(0.4779)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0152])
# Train sample accuracy:  tensor(0.9848)
# tensor(0.4871)
# % positive predictions:  tensor([0.6262]) % Positive targets :  tensor([0.1405])
# Train sample accuracy:  tensor(0.4048)
# % of positive predictions:  0.125
#                     accuracy  precision   recall   roc_auc
# Micriobiome TabPFN  0.831428   0.060862  0.11938  0.498902
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 254.97s | mean loss  0.65 |  lr8.422735529643443e-07 |  data time  0.03 step time  0.98 forward time  0.35 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4383)
# % positive predictions:  tensor([0.6657]) % Positive targets :  tensor([0.1895])
# Train sample accuracy:  tensor(0.4585)
# tensor(0.4464)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.4640])
# Train sample accuracy:  tensor(0.4640)
# tensor(0.4587)
# % positive predictions:  tensor([0.1828]) % Positive targets :  tensor([0.1100])
# Train sample accuracy:  tensor(0.7460)
# tensor(0.4788)
# % positive predictions:  tensor([0.0108]) % Positive targets :  tensor([0.0136])
# Train sample accuracy:  tensor(0.9774)
# % of positive predictions:  0.15
#                     accuracy  precision    recall  roc_auc
# Micriobiome TabPFN  0.827938   0.062952  0.125544  0.50014
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 248.89s | mean loss  0.65 |  lr8.187119948743449e-07 |  data time  0.02 step time  0.70 forward time  0.23 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5278)
# % positive predictions:  tensor([0.1660]) % Positive targets :  tensor([0.2104])
# Train sample accuracy:  tensor(0.7761)
# tensor(0.5619)
# % positive predictions:  tensor([0.7547]) % Positive targets :  tensor([0.9488])
# Train sample accuracy:  tensor(0.7466)
# tensor(0.5256)
# % positive predictions:  tensor([0.5489]) % Positive targets :  tensor([0.7362])
# Train sample accuracy:  tensor(0.5745)
# tensor(0.4978)
# % positive predictions:  tensor([0.0124]) % Positive targets :  tensor([0.0290])
# Train sample accuracy:  tensor(0.9668)
# % of positive predictions:  0.115
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.849054   0.067121  0.103931  0.501877
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 257.55s | mean loss  0.65 |  lr7.938926261462365e-07 |  data time  0.01 step time  1.33 forward time  0.47 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5236)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.])
# Train sample accuracy:  tensor(1.)
# tensor(0.5214)
# % positive predictions:  tensor([0.0750]) % Positive targets :  tensor([0.1536])
# Train sample accuracy:  tensor(0.7934)
# tensor(0.5162)
# % positive predictions:  tensor([0.3898]) % Positive targets :  tensor([0.3797])
# Train sample accuracy:  tensor(0.5559)
# tensor(0.5238)
# % positive predictions:  tensor([0.8136]) % Positive targets :  tensor([0.0050])
# Train sample accuracy:  tensor(0.1914)
# % of positive predictions:  0.06
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.858738   0.064797  0.099086  0.503467
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 251.56s | mean loss  0.66 |  lr7.679133974894982e-07 |  data time  0.02 step time  0.81 forward time  0.27 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4656)
# % positive predictions:  tensor([0.1559]) % Positive targets :  tensor([0.0108])
# Train sample accuracy:  tensor(0.8333)
# tensor(0.4708)
# % positive predictions:  tensor([0.0934]) % Positive targets :  tensor([0.5623])
# Train sample accuracy:  tensor(0.4721)
# tensor(0.4794)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0303])
# Train sample accuracy:  tensor(0.9697)
# tensor(0.4771)
# % positive predictions:  tensor([0.9801]) % Positive targets :  tensor([0.9453])
# Train sample accuracy:  tensor(0.9254)
# % of positive predictions:  0.105
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.869993   0.063178  0.082803  0.501864
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 262.31s | mean loss  0.64 |  lr7.408768370508576e-07 |  data time  0.02 step time  1.27 forward time  0.46 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5318)
# % positive predictions:  tensor([0.1787]) % Positive targets :  tensor([0.3009])
# Train sample accuracy:  tensor(0.5919)
# tensor(0.4845)
# % positive predictions:  tensor([0.0134]) % Positive targets :  tensor([0.2255])
# Train sample accuracy:  tensor(0.7641)
# tensor(0.5139)
# % positive predictions:  tensor([0.7278]) % Positive targets :  tensor([0.8085])
# Train sample accuracy:  tensor(0.5649)
# tensor(0.5043)
# % positive predictions:  tensor([0.7028]) % Positive targets :  tensor([0.5529])
# Train sample accuracy:  tensor(0.5850)
# % of positive predictions:  0.065
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.871302   0.055472  0.071454  0.496758
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 255.80s | mean loss  0.64 |  lr7.128896457825363e-07 |  data time  0.02 step time  1.02 forward time  0.34 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4247)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0137])
# Train sample accuracy:  tensor(0.9863)
# tensor(0.5047)
# % positive predictions:  tensor([0.7101]) % Positive targets :  tensor([0.8827])
# Train sample accuracy:  tensor(0.7101)
# tensor(0.5046)
# % positive predictions:  tensor([0.7804]) % Positive targets :  tensor([0.6022])
# Train sample accuracy:  tensor(0.5566)
# tensor(0.5155)
# % positive predictions:  tensor([0.2331]) % Positive targets :  tensor([0.1286])
# Train sample accuracy:  tensor(0.7060)
# % of positive predictions:  0.09
#                     accuracy  precision    recall  roc_auc
# Micriobiome TabPFN  0.880377   0.074845  0.081297  0.50734
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 250.14s | mean loss  0.63 |  lr6.840622763423391e-07 |  data time  0.02 step time  0.67 forward time  0.20 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4892)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.9683])
# Train sample accuracy:  tensor(0.9683)
# tensor(0.5259)
# % positive predictions:  tensor([0.9210]) % Positive targets :  tensor([0.7823])
# Train sample accuracy:  tensor(0.7264)
# tensor(0.5248)
# % positive predictions:  tensor([0.1600]) % Positive targets :  tensor([0.0019])
# Train sample accuracy:  tensor(0.8381)
# tensor(0.5284)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0081])
# Train sample accuracy:  tensor(0.9919)
# % of positive predictions:  0.04
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.886223   0.069763  0.069892  0.504562
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 246.67s | mean loss  0.64 |  lr6.545084971874736e-07 |  data time  0.02 step time  1.11 forward time  0.38 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5814)
# % positive predictions:  tensor([0.0009]) % Positive targets :  tensor([0.9973])
# Train sample accuracy:  tensor(0.0036)
# tensor(0.5179)
# % positive predictions:  tensor([0.0939]) % Positive targets :  tensor([0.0018])
# Train sample accuracy:  tensor(0.9042)
# tensor(0.4986)
# % positive predictions:  tensor([0.5447]) % Positive targets :  tensor([0.3362])
# Train sample accuracy:  tensor(0.4794)
# tensor(0.4956)
# % positive predictions:  tensor([0.9624]) % Positive targets :  tensor([0.9946])
# Train sample accuracy:  tensor(0.9570)
# % of positive predictions:  0.045
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.893289   0.061179  0.049811  0.499575
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 253.93s | mean loss  0.63 |  lr6.243449435824276e-07 |  data time  0.02 step time  0.65 forward time  0.19 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4974)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.7874])
# Train sample accuracy:  tensor(0.7874)
# tensor(0.5544)
# % positive predictions:  tensor([0.3859]) % Positive targets :  tensor([0.2743])
# Train sample accuracy:  tensor(0.4830)
# tensor(0.5343)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0102])
# Train sample accuracy:  tensor(0.9898)
# tensor(0.5317)
# % positive predictions:  tensor([0.0922]) % Positive targets :  tensor([0.9823])
# Train sample accuracy:  tensor(0.1099)
# % of positive predictions:  0.02
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.904111   0.048643  0.033572  0.497294
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 249.14s | mean loss  0.64 |  lr5.936906572928624e-07 |  data time  0.01 step time  1.07 forward time  0.37 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5186)
# % positive predictions:  tensor([0.3528]) % Positive targets :  tensor([0.1144])
# Train sample accuracy:  tensor(0.6545)
# tensor(0.5265)
# % positive predictions:  tensor([0.1787]) % Positive targets :  tensor([0.0320])
# Train sample accuracy:  tensor(0.7911)
# tensor(0.5104)
# % positive predictions:  tensor([0.9666]) % Positive targets :  tensor([0.7838])
# Train sample accuracy:  tensor(0.7599)
# tensor(0.5161)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.9696])
# Train sample accuracy:  tensor(0.9696)
# % of positive predictions:  0.045
#                     accuracy  precision    recall  roc_auc
# Micriobiome TabPFN  0.907948   0.057899  0.034191  0.49944
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 256.01s | mean loss  0.63 |  lr5.626666167821521e-07 |  data time  0.02 step time  1.39 forward time  0.52 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5292)
# % positive predictions:  tensor([0.8262]) % Positive targets :  tensor([0.7742])
# Train sample accuracy:  tensor(0.6338)
# tensor(0.5359)
# % positive predictions:  tensor([0.6674]) % Positive targets :  tensor([0.9932])
# Train sample accuracy:  tensor(0.6651)
# tensor(0.5411)
# % positive predictions:  tensor([0.9930]) % Positive targets :  tensor([0.8894])
# Train sample accuracy:  tensor(0.8847)
# tensor(0.5674)
# % positive predictions:  tensor([0.4778]) % Positive targets :  tensor([0.0129])
# Train sample accuracy:  tensor(0.5093)
# % of positive predictions:  0.045
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.913882   0.035251  0.015805  0.493875
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 245.73s | mean loss  0.63 |  lr5.313952597646567e-07 |  data time  0.02 step time  0.93 forward time  0.30 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5620)
# % positive predictions:  tensor([0.3682]) % Positive targets :  tensor([0.1036])
# Train sample accuracy:  tensor(0.6009)
# tensor(0.5284)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0026])
# Train sample accuracy:  tensor(0.9974)
# tensor(0.5599)
# % positive predictions:  tensor([0.9729]) % Positive targets :  tensor([0.9632])
# Train sample accuracy:  tensor(0.9360)
# tensor(0.5527)
# % positive predictions:  tensor([0.5132]) % Positive targets :  tensor([0.9943])
# Train sample accuracy:  tensor(0.5189)
# % of positive predictions:  0.01
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.917982   0.038192  0.014481  0.495349
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 236.56s | mean loss  0.62 |  lr5e-07 |  data time  0.01 step time  0.77 forward time  0.24 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4337)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.9888])
# Train sample accuracy:  tensor(0.9888)
# tensor(0.4428)
# % positive predictions:  tensor([0.0906]) % Positive targets :  tensor([0.0915])
# Train sample accuracy:  tensor(0.8199)
# tensor(0.4710)
# % positive predictions:  tensor([0.0340]) % Positive targets :  tensor([0.1085])
# Train sample accuracy:  tensor(0.8702)
# tensor(0.4959)
# % positive predictions:  tensor([0.8413]) % Positive targets :  tensor([0.9921])
# Train sample accuracy:  tensor(0.8413)
# % of positive predictions:  0.015
#                     accuracy  precision    recall  roc_auc
# Micriobiome TabPFN  0.922258   0.038257  0.009899  0.49625
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 249.80s | mean loss  0.64 |  lr4.686047402353433e-07 |  data time  0.02 step time  1.14 forward time  0.45 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4580)
# % positive predictions:  tensor([0.8889]) % Positive targets :  tensor([0.9828])
# Train sample accuracy:  tensor(0.8716)
# tensor(0.4488)
# % positive predictions:  tensor([0.4861]) % Positive targets :  tensor([0.4060])
# Train sample accuracy:  tensor(0.8600)
# tensor(0.4458)
# % positive predictions:  tensor([0.6147]) % Positive targets :  tensor([0.4566])
# Train sample accuracy:  tensor(0.4610)
# tensor(0.4619)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0069])
# Train sample accuracy:  tensor(0.9931)
# % of positive predictions:  0.005
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN   0.92601   0.037959  0.012571  0.497775
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 238.01s | mean loss  0.64 |  lr4.3733338321784777e-07 |  data time  0.02 step time  1.09 forward time  0.42 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5563)
# % positive predictions:  tensor([0.7607]) % Positive targets :  tensor([0.0037])
# Train sample accuracy:  tensor(0.2393)
# tensor(0.5347)
# % positive predictions:  tensor([0.9950]) % Positive targets :  tensor([1.])
# Train sample accuracy:  tensor(0.9950)
# tensor(0.5263)
# % positive predictions:  tensor([0.9160]) % Positive targets :  tensor([0.9568])
# Train sample accuracy:  tensor(0.8800)
# tensor(0.5250)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.1208])
# Train sample accuracy:  tensor(0.8792)
# % of positive predictions:  0.015
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.926533   0.065403  0.012496  0.500242
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 247.06s | mean loss  0.62 |  lr4.0630934270713755e-07 |  data time  0.02 step time  0.96 forward time  0.35 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5648)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.9531])
# Train sample accuracy:  tensor(0.9531)
# tensor(0.5263)
# % positive predictions:  tensor([0.2127]) % Positive targets :  tensor([0.2095])
# Train sample accuracy:  tensor(0.9905)
# tensor(0.5220)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.9921])
# Train sample accuracy:  tensor(0.9921)
# tensor(0.5127)
# % positive predictions:  tensor([0.4494]) % Positive targets :  tensor([0.9108])
# Train sample accuracy:  tensor(0.3602)
# % of positive predictions:  0.01
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.930983   0.089139  0.015955  0.502779
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 248.81s | mean loss  0.63 |  lr3.7565505641757266e-07 |  data time  0.02 step time  0.83 forward time  0.29 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4542)
# % positive predictions:  tensor([0.3662]) % Positive targets :  tensor([0.2873])
# Train sample accuracy:  tensor(0.5437)
# tensor(0.4407)
# % positive predictions:  tensor([0.8123]) % Positive targets :  tensor([0.9888])
# Train sample accuracy:  tensor(0.8011)
# tensor(0.4473)
# % positive predictions:  tensor([0.1152]) % Positive targets :  tensor([0.6073])
# Train sample accuracy:  tensor(0.4555)
# tensor(0.4445)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.4763])
# Train sample accuracy:  tensor(0.4763)
# % of positive predictions:  0.01
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.924614   0.066328  0.012281  0.499614
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 251.40s | mean loss  0.61 |  lr3.454915028125263e-07 |  data time  0.01 step time  1.25 forward time  0.45 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.3681)
# % positive predictions:  tensor([0.1571]) % Positive targets :  tensor([0.0143])
# Train sample accuracy:  tensor(0.8286)
# tensor(0.4671)
# % positive predictions:  tensor([0.5065]) % Positive targets :  tensor([0.5351])
# Train sample accuracy:  tensor(0.3330)
# tensor(0.4816)
# % positive predictions:  tensor([0.9650]) % Positive targets :  tensor([0.9755])
# Train sample accuracy:  tensor(0.9429)
# tensor(0.4907)
# % positive predictions:  tensor([0.5291]) % Positive targets :  tensor([0.0673])
# Train sample accuracy:  tensor(0.4893)
# % of positive predictions:  0.005
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.928541   0.048501  0.005556  0.498259
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 249.75s | mean loss  0.62 |  lr3.15937723657661e-07 |  data time  0.02 step time  1.14 forward time  0.40 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5100)
# % positive predictions:  tensor([0.0089]) % Positive targets :  tensor([0.0285])
# Train sample accuracy:  tensor(0.9626)
# tensor(0.5486)
# % positive predictions:  tensor([0.9783]) % Positive targets :  tensor([0.9845])
# Train sample accuracy:  tensor(0.9690)
# tensor(0.5270)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.7128])
# Train sample accuracy:  tensor(0.7128)
# tensor(0.5444)
# % positive predictions:  tensor([0.8543]) % Positive targets :  tensor([0.4422])
# Train sample accuracy:  tensor(0.4874)
# % of positive predictions:  0.01
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.926358   0.070793  0.013714  0.500801
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 242.21s | mean loss  0.62 |  lr2.8711035421746363e-07 |  data time  0.02 step time  1.15 forward time  0.44 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4094)
# % positive predictions:  tensor([0.7669]) % Positive targets :  tensor([0.0479])
# Train sample accuracy:  tensor(0.1852)
# tensor(0.5013)
# % positive predictions:  tensor([0.0024]) % Positive targets :  tensor([0.0309])
# Train sample accuracy:  tensor(0.9715)
# tensor(0.5142)
# % positive predictions:  tensor([0.5063]) % Positive targets :  tensor([0.1164])
# Train sample accuracy:  tensor(0.4780)
# tensor(0.5256)
# % positive predictions:  tensor([0.7902]) % Positive targets :  tensor([0.])
# Train sample accuracy:  tensor(0.2098)
# % of positive predictions:  0.005
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.932118   0.065278  0.010234  0.500431
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 259.39s | mean loss  0.61 |  lr2.591231629491423e-07 |  data time  0.02 step time  1.08 forward time  0.41 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5891)
# % positive predictions:  tensor([0.0193]) % Positive targets :  tensor([0.8564])
# Train sample accuracy:  tensor(0.1589)
# tensor(0.5481)
# % positive predictions:  tensor([0.0062]) % Positive targets :  tensor([0.9863])
# Train sample accuracy:  tensor(0.0200)
# tensor(0.5238)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.5234])
# Train sample accuracy:  tensor(0.4766)
# tensor(0.5371)
# % positive predictions:  tensor([0.0011]) % Positive targets :  tensor([0.0427])
# Train sample accuracy:  tensor(0.9562)
# % of positive predictions:  0.03
#                     accuracy  precision    recall  roc_auc
# Micriobiome TabPFN  0.930983   0.042622  0.005687  0.49843
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 249.65s | mean loss  0.61 |  lr2.3208660251050156e-07 |  data time  0.02 step time  0.87 forward time  0.28 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5010)
# % positive predictions:  tensor([0.1933]) % Positive targets :  tensor([0.0191])
# Train sample accuracy:  tensor(0.8019)
# tensor(0.5434)
# % positive predictions:  tensor([0.0234]) % Positive targets :  tensor([0.0607])
# Train sample accuracy:  tensor(0.9252)
# tensor(0.5432)
# % positive predictions:  tensor([0.2078]) % Positive targets :  tensor([0.2865])
# Train sample accuracy:  tensor(0.6556)
# tensor(0.5255)
# % positive predictions:  tensor([0.5947]) % Positive targets :  tensor([0.8880])
# Train sample accuracy:  tensor(0.5787)
# % of positive predictions:  0.005
#                     accuracy  precision    recall  roc_auc
# Micriobiome TabPFN   0.93203   0.021869  0.002883  0.49708
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 255.52s | mean loss  0.60 |  lr2.0610737385376348e-07 |  data time  0.02 step time  1.25 forward time  0.44 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4945)
# % positive predictions:  tensor([0.9156]) % Positive targets :  tensor([0.9295])
# Train sample accuracy:  tensor(0.8520)
# tensor(0.5181)
# % positive predictions:  tensor([0.0100]) % Positive targets :  tensor([0.0122])
# Train sample accuracy:  tensor(0.9800)
# tensor(0.5209)
# % positive predictions:  tensor([0.0141]) % Positive targets :  tensor([0.2653])
# Train sample accuracy:  tensor(0.7206)
# tensor(0.5333)
# % positive predictions:  tensor([0.2578]) % Positive targets :  tensor([0.0179])
# Train sample accuracy:  tensor(0.7394)
# % of positive predictions:  0.02
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN   0.93491   0.025604  0.003086  0.498067
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 251.05s | mean loss  0.61 |  lr1.812880051256551e-07 |  data time  0.02 step time  0.71 forward time  0.25 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4561)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.1777])
# Train sample accuracy:  tensor(0.8223)
# tensor(0.4575)
# % positive predictions:  tensor([0.5304]) % Positive targets :  tensor([0.4824])
# Train sample accuracy:  tensor(0.4728)
# tensor(0.4759)
# % positive predictions:  tensor([0.0126]) % Positive targets :  tensor([0.7846])
# Train sample accuracy:  tensor(0.2056)
# tensor(0.4848)
# % positive predictions:  tensor([0.0420]) % Positive targets :  tensor([0.0309])
# Train sample accuracy:  tensor(0.9272)
# % of positive predictions:  0.02
#                     accuracy  precision   recall   roc_auc
# Micriobiome TabPFN  0.932815   0.014493  0.00155  0.497152
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 247.74s | mean loss  0.61 |  lr1.5772644703565564e-07 |  data time  0.02 step time  0.96 forward time  0.32 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5577)
# % positive predictions:  tensor([0.0270]) % Positive targets :  tensor([0.0063])
# Train sample accuracy:  tensor(0.9667)
# tensor(0.5010)
# % positive predictions:  tensor([0.6587]) % Positive targets :  tensor([0.5397])
# Train sample accuracy:  tensor(0.4493)
# tensor(0.5104)
# % positive predictions:  tensor([0.0673]) % Positive targets :  tensor([0.0205])
# Train sample accuracy:  tensor(0.9532)
# tensor(0.5201)
# % positive predictions:  tensor([0.0836]) % Positive targets :  tensor([0.1105])
# Train sample accuracy:  tensor(0.8173)
# % of positive predictions:  0.0
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.932293   0.057922  0.008557  0.499822
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 248.10s | mean loss  0.61 |  lr1.3551568628929432e-07 |  data time  0.02 step time  0.87 forward time  0.31 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4921)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.8912])
# Train sample accuracy:  tensor(0.8912)
# tensor(0.5471)
# % positive predictions:  tensor([0.6167]) % Positive targets :  tensor([0.1153])
# Train sample accuracy:  tensor(0.4063)
# tensor(0.5011)
# % positive predictions:  tensor([0.2824]) % Positive targets :  tensor([0.1674])
# Train sample accuracy:  tensor(0.7191)
# tensor(0.5141)
# % positive predictions:  tensor([0.1654]) % Positive targets :  tensor([0.0026])
# Train sample accuracy:  tensor(0.8320)
# % of positive predictions:  0.0
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.931593   0.066117  0.006822  0.500197
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 257.46s | mean loss  0.62 |  lr1.1474337861210543e-07 |  data time  0.02 step time  0.86 forward time  0.29 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5133)
# % positive predictions:  tensor([0.7157]) % Positive targets :  tensor([0.3401])
# Train sample accuracy:  tensor(0.5228)
# tensor(0.5459)
# % positive predictions:  tensor([0.1850]) % Positive targets :  tensor([0.5625])
# Train sample accuracy:  tensor(0.5325)
# tensor(0.5546)
# % positive predictions:  tensor([0.0161]) % Positive targets :  tensor([0.7533])
# Train sample accuracy:  tensor(0.2552)
# tensor(0.5316)
# % positive predictions:  tensor([0.0082]) % Positive targets :  tensor([0.0129])
# Train sample accuracy:  tensor(0.9813)
# % of positive predictions:  0.0
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.934648   0.089418  0.010354  0.501696
# -----------------------------------------------------------------------------------------
# | end of epoch  41 | time: 254.43s | mean loss  0.61 |  lr9.549150281252632e-08 |  data time  0.02 step time  0.93 forward time  0.31 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5235)
# % positive predictions:  tensor([0.0854]) % Positive targets :  tensor([0.2991])
# Train sample accuracy:  tensor(0.6182)
# tensor(0.5081)
# % positive predictions:  tensor([0.9982]) % Positive targets :  tensor([0.9928])
# Train sample accuracy:  tensor(0.9910)
# tensor(0.5218)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.8268])
# Train sample accuracy:  tensor(0.8268)
# tensor(0.5215)
# % positive predictions:  tensor([0.9938]) % Positive targets :  tensor([0.4085])
# Train sample accuracy:  tensor(0.4148)
# % of positive predictions:  0.0
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.934823   0.015873  0.001418  0.498155
# -----------------------------------------------------------------------------------------
# | end of epoch  42 | time: 250.15s | mean loss  0.61 |  lr7.783603724899257e-08 |  data time  0.02 step time  0.72 forward time  0.23 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5874)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.9689])
# Train sample accuracy:  tensor(0.9689)
# tensor(0.5135)
# % positive predictions:  tensor([1.]) % Positive targets :  tensor([0.9376])
# Train sample accuracy:  tensor(0.9376)
# tensor(0.5034)
# % positive predictions:  tensor([0.3843]) % Positive targets :  tensor([0.6390])
# Train sample accuracy:  tensor(0.4593)
# tensor(0.5306)
# % positive predictions:  tensor([0.0012]) % Positive targets :  tensor([0.0093])
# Train sample accuracy:  tensor(0.9896)
# % of positive predictions:  0.0
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.935259   0.014493  0.001395  0.498098
# -----------------------------------------------------------------------------------------
# | end of epoch  43 | time: 252.88s | mean loss  0.61 |  lr6.184665997806826e-08 |  data time  0.02 step time  0.84 forward time  0.26 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4754)
# % positive predictions:  tensor([0.9342]) % Positive targets :  tensor([0.9918])
# Train sample accuracy:  tensor(0.9259)
# tensor(0.4899)
# % positive predictions:  tensor([0.0063]) % Positive targets :  tensor([0.0032])
# Train sample accuracy:  tensor(0.9905)
# tensor(0.5024)
# % positive predictions:  tensor([0.9686]) % Positive targets :  tensor([0.8050])
# Train sample accuracy:  tensor(0.7987)
# tensor(0.5044)
# % positive predictions:  tensor([0.0051]) % Positive targets :  tensor([0.2308])
# Train sample accuracy:  tensor(0.7744)
# % of positive predictions:  0.0
#                     accuracy  precision    recall   roc_auc
# Micriobiome TabPFN  0.932467   0.027778  0.002831  0.497748
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time: 258.62s | mean loss  0.63 |  lr4.758647376699032e-08 |  data time  0.02 step time  1.23 forward time  0.43 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5637)
# % positive predictions:  tensor([0.9692]) % Positive targets :  tensor([0.9988])
# Train sample accuracy:  tensor(0.9680)
# tensor(0.4962)
# % positive predictions:  tensor([0.3570]) % Positive targets :  tensor([0.0048])
# Train sample accuracy:  tensor(0.6478)
# tensor(0.5064)
# % positive predictions:  tensor([0.0561]) % Positive targets :  tensor([0.1060])
# Train sample accuracy:  tensor(0.8502)
# tensor(0.5141)
# % positive predictions:  tensor([0.9394]) % Positive targets :  tensor([0.2912])
# Train sample accuracy:  tensor(0.2306)
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# % of positive predictions:  0.0
#                     accuracy  precision  recall  roc_auc
# Micriobiome TabPFN  0.938138        0.0     0.0      0.5
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time: 248.04s | mean loss  0.61 |  lr3.5111757055874326e-08 |  data time  0.02 step time  0.95 forward time  0.34 nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4859)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0713])
# Train sample accuracy:  tensor(0.9287)
# tensor(0.5054)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.1431])
# Train sample accuracy:  tensor(0.8569)
# tensor(0.5102)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.3444])
# Train sample accuracy:  tensor(0.6556)
# tensor(0.5022)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0058])
# Train sample accuracy:  tensor(0.9942)
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# % of positive predictions:  0.0
#                     accuracy  precision  recall  roc_auc
# Micriobiome TabPFN  0.938924        0.0     0.0      0.5
# -----------------------------------------------------------------------------------------
# | end of epoch  46 | time: 239.46s | mean loss  0.00 |  lr2.4471741852423233e-08 |  data time  0.01 step time  0.66 forward time  0.19 nan share  1.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.4322)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0298])
# Train sample accuracy:  tensor(0.9702)
# tensor(0.4819)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.9291])
# Train sample accuracy:  tensor(0.0709)
# tensor(0.4616)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0337])
# Train sample accuracy:  tensor(0.9663)
# tensor(0.4638)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.5520])
# Train sample accuracy:  tensor(0.4480)
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# % of positive predictions:  0.0
#                     accuracy  precision  recall  roc_auc
# Micriobiome TabPFN  0.939272        0.0     0.0      0.5
# -----------------------------------------------------------------------------------------
# | end of epoch  47 | time: 251.44s | mean loss  0.00 |  lr1.570841943568446e-08 |  data time  0.03 step time  1.06 forward time  0.39 nan share  1.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5558)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.4083])
# Train sample accuracy:  tensor(0.5917)
# tensor(0.5601)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.7727])
# Train sample accuracy:  tensor(0.2273)
# tensor(0.5131)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0034])
# Train sample accuracy:  tensor(0.9966)
# tensor(0.5089)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.9895])
# Train sample accuracy:  tensor(0.0105)
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# % of positive predictions:  0.0
#                     accuracy  precision  recall  roc_auc
# Micriobiome TabPFN  0.934997        0.0     0.0      0.5
# -----------------------------------------------------------------------------------------
# | end of epoch  48 | time: 240.50s | mean loss  0.00 |  lr8.856374635655695e-09 |  data time  0.02 step time  0.74 forward time  0.23 nan share  1.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5570)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.6733])
# Train sample accuracy:  tensor(0.3267)
# tensor(0.5201)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.9919])
# Train sample accuracy:  tensor(0.0081)
# tensor(0.4967)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.1159])
# Train sample accuracy:  tensor(0.8841)
# tensor(0.5095)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.1102])
# Train sample accuracy:  tensor(0.8898)
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# % of positive predictions:  0.0
#                     accuracy  precision  recall  roc_auc
# Micriobiome TabPFN  0.939185        0.0     0.0      0.5
# -----------------------------------------------------------------------------------------
# | end of epoch  49 | time: 242.40s | mean loss  0.00 |  lr3.9426493427611175e-09 |  data time  0.02 step time  0.81 forward time  0.25 nan share  1.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# tensor(0.5812)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.7673])
# Train sample accuracy:  tensor(0.2327)
# tensor(0.5308)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.0073])
# Train sample accuracy:  tensor(0.9927)
# tensor(0.5233)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.5046])
# Train sample accuracy:  tensor(0.4954)
# tensor(0.5282)
# % positive predictions:  tensor([0.]) % Positive targets :  tensor([0.2032])
# Train sample accuracy:  tensor(0.7968)
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\lenna\anaconda3\envs\master3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# % of positive predictions:  0.0
#                     accuracy  precision  recall  roc_auc
# Micriobiome TabPFN  0.941105        0.0     0.0      0.5
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time: 240.65s | mean loss  0.00 |  lr9.866357858642205e-10 |  data time  0.02 step time  1.01 forward time  0.37 nan share  1.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------

# %%
import os
def load_train_results(name):
    dir_path = os.path.abspath(os.getcwd())
    path = dir_path + f"/logs/trainrun_{name}"
    losses = torch.load(path+"/losses")
    mb_results = torch.load(path+"/mb_results")
    return losses, mb_results

# %%
def plot_metrics(losses, results, metrics, name):
    plt.figure(1)
    plt.subplot(211)
    for ii, m in enumerate(metrics):
        plt.plot(results[:,ii], label=m)
    plt.ylabel("score")
    plt.title(name)
    plt.legend()
    plt.subplot(212)
    plt.plot(losses)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.show()

# %%
name = "forest_nonorm"
metrics = ["accuracy", "precision", "recall", "roc_auc"]
losses, mb_results = load_train_results(name)
plot_metrics(losses, mb_results, metrics, name)
